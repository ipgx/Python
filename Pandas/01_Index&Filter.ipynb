# %%
# Import pandas and set display options for notebook output
import pandas as pd

# Make wide tables easier to read in the notebook output
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
# Read the main survey CSV and the schema file.
# Note: pandas may emit a DtypeWarning for mixed-type columns; this is expected for large survey exports.
stackOverflow_survey = pd.read_csv('data/survey_results_public.csv')
# The schema file maps columns to questions that were asked
stackOverflow_survey_schema = pd.read_csv('data/survey_results_schema.csv')
# Out:
# C:\Users\paragg\AppData\Local\Temp\ipykernel_23516\594922714.py:3: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   stackOverflow_survey = pd.read_csv('data/survey_results_public.csv')

# %% [markdown]
# ## Each dataframe is made of three components
# - Columns
# - Values
# - Indices

# %%
stackOverflow_survey.values
# Out:
# array([[1, 'I am a developer by profession', '25-34 years old', ...,
#         'Troubleshooting, profiling, debugging', 61256.0, 10.0],
#        [2, 'I am a developer by profession', '25-34 years old', ...,
#         'All skills. AI is a flop.', 104413.0, 9.0],
#        [3, 'I am a developer by profession', '35-44 years old', ...,
#         'Understand how things actually work, problem solving, and algorithms',
#         53061.0, 8.0],
#        ...,
#        [49189, 'I am a developer by profession', '35-44 years old', ...,
#         nan, nan, 9.0],
#        [49190, 'I am a developer by profession', '25-34 years old', ...,
#         nan, nan, nan],
#        [49191,
#         'I am not primarily a developer, but I write code sometimes as part of my work/studies',
#         '18-24 years old', ..., nan, nan, nan]],
#       shape=(49191, 172), dtype=object)

# %%
stackOverflow_survey.index
# Out:
# RangeIndex(start=0, stop=49191, step=1)

# %%
stackOverflow_survey.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=172)
