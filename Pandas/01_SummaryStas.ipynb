# %%
import pandas as pd

sales = pd.read_csv('data/sales.csv')
sales.head()
# Out:
#    store type  department        date  weekly_sales  is_holiday  \
# 0      1    A           6  2009-07-11      37246.23       False
# 1      1    A           7  2010-04-20      25857.08       False
# 2      1    A           5  2010-10-28      13351.08       False
# 3      1    A           7  2010-06-26      15998.72       False
# 4      1    A           4  2010-04-29      32233.11       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0         26.312                 0.655         7.704
# 1         11.095                 0.736         7.951
# 2         21.461                 0.683         7.963
# 3         28.705                 0.707         7.807
# 4         21.988                 0.773         7.810

# %%
# Print the info about the sales DataFrame
print(sales.info())

# Print the mean of weekly_sales
print(sales['weekly_sales'].mean())

# Print the median of weekly_sales
print(sales['weekly_sales'].median())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store                 400 non-null    int64
#  1   type                  400 non-null    object
#  2   department            400 non-null    int64
#  3   date                  400 non-null    object
#  4   weekly_sales          400 non-null    float64
#  5   is_holiday            400 non-null    bool
#  6   temperature_c         400 non-null    float64
#  7   fuel_price_usd_per_l  400 non-null    float64
#  8   unemployment          400 non-null    float64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 25.5+ KB
# None
# 24959.1387
# 24616.83
